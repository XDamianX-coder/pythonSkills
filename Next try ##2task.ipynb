# %%
from __future__ import print_function
from rdkit import Chem
import sys
from rdkit import Chem
from rdkit.Chem import AllChem, TorsionFingerprints
from rdkit.ML.Cluster import Butina
import pandas as pd

# %%
smi_input_file = sys.argv[1]

# %%
smi_output_file = sys.argv[2]

# %%
n = int(sys.argv[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-040406575523> in <module>()
# ----> 1 n = int(sys.argv[3])
#
# IndexError: list index out of range

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# %%
penicillin_g_smiles = 'CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)Cc3ccccc3)C(=O)O)C'

# %%
penicillin_g = Chem.MolFromSmiles(penicillin_g_smiles)

# %%
Draw.MolToMPL(penicillin_g, size=(200, 200))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-4bd7b3efbe8f> in <module>()
# ----> 1 Draw.MolToMPL(penicillin_g, size=(200, 200))
#
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\rdkit\Chem\Draw\__init__.pyc in MolToMPL(mol, size, kekulize, wedgeBonds, imageType, fitImage, options, **kwargs)
#     233   if not mol:
#     234     raise ValueError('Null molecule provided')
# --> 235   from rdkit.Chem.Draw.mplCanvas import Canvas
#     236   canvas = Canvas(size)
#     237   if options is None:
#
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\rdkit\Chem\Draw\mplCanvas.py in <module>()
#       8 #  of the RDKit source tree.
#       9 #
# ---> 10 from matplotlib.lines import Line2D
#      11 from matplotlib.patches import Polygon
#      12 from matplotlib.pyplot import figure
#
# ...

# %%
from __future__ import print_function
from rdkit import Chem
import sys
from rdkit import Chem
from rdkit.Chem import AllChem, TorsionFingerprints
from rdkit.ML.Cluster import Butina
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
penicillin_g_smiles = 'CC1([C@@H](N2[C@H](S1)[C@@H](C2=O)NC(=O)Cc3ccccc3)C(=O)O)C'

# %%
penicillin_g = Chem.MolFromSmiles(penicillin_g_smiles)

# %%
Draw.MolToMPL(penicillin_g, size=(200, 200))

# %% [markdown]
# I'm trying to create MOL objects from CSV file.

# %%
data = pd.read_csv("sampleMolecules.csv")

# %%
data
# Out:
#    molregNoMin  molregNoCount  \
# 0      1522827              2
# 1       612901              2
# 2       171018              1
# 3        11414              4
# 4       135826              1
# 5      1840523              5
# 6      1973470              1
# 7      1970195              1
# 8      1576644              3
#
#                                         chemblSmiles  standardMin  \
# 0        CNC(=S)N\N=C(\c1ccc(OC)c(OC)c1)/c2cccc(C)n2       6250.0
# 1  Cn1cc(C2=C(C(=O)NC2=O)c3cccc(NCC(O)CO)c3)c4cc(...          0.4
# 2                CC(C)c1cccc(C(C)C)c1N2Sc3ncccc3C2=O      12000.0
# 3  O[C@@H](CNCCc1ccc(NS(=O)(=O)c2ccc(I)cc2)cc1)CO...        120.0
# 4  C\C(=C/C\C(=C\CCC1=CC(=O)OC1O)\C)\CCC2=C(C)CCC...     990000.0
# 5  CNC(=O)[C@]1(C)CC[C@]2(C)CC[C@]3(C)C4=CC=C5C(=...       7620.0
# 6                               C#Cc1cncc(c1)c2ccsc2      12900.0
# 7  C[C@H](C[C@H](O)[C@H](O)C(=C)C)C1=C2C=C[C@H]3[...       8680.0
# ...

# %%
smilesCodes = data['canonicalSmiles'].values

# %%
def formsmilesintomol(smilesCodes):
    m = Chem.MolFromSmiles(smilesCode)
    return(Chem.MolFromSmiles(m))

# %%
formsmilesintomol(smilesCode[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5b52b167aa67> in <module>()
# ----> 1 formsmilesintomol(smilesCode[3])
#
# NameError: name 'smilesCode' is not defined

# %%
smilesCode = data['canonicalSmiles'].values

# %%
def formsmilesintomol(smilesCode):
    m = Chem.MolFromSmiles(smilesCode)
    return(Chem.MolFromSmiles(m))

# %%
formsmilesintomol(smilesCode[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-80172077e68a> in <module>()
# ----> 1 formsmilesintomol(smilesCode[2])
#
# <ipython-input-12-0a762a1b8d9c> in formsmilesintomol(smilesCode)
#       1 def formsmilesintomol(smilesCode):
#       2     m = Chem.MolFromSmiles(smilesCode)
# ----> 3     return(Chem.MolFromSmiles(m))
#
# TypeError: No registered converter was able to produce a C++ rvalue of type class std::basic_string<wchar_t,struct std::char_traits<wchar_t>,class std::allocator<wchar_t> > from this Python object of type Mol

# %%
def addHs(smilesCode):
    m = Chem.MolFromSmiles(smilesCode)
    return(Chem.AddHs(m))

# %%
addHs(smilesCode[1])

# %% [markdown]
# Należy stworzyć objekt, który będzie poprawnie odczytywany.

# %%
smi_input_file = sys.argv[1]

# %%
smi_output_file = sys.argv[2]

# %%
n = int(sys.argv[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-040406575523> in <module>()
# ----> 1 n = int(sys.argv[3])
#
# IndexError: list index out of range

# %% [markdown]
# Jak zdefiniować inną listę?

# %%
smilesCode[4]
# Out:
# 'CC(=CCCC1=CC(=O)OC1O)CC=C(C)CCC1=C(C)CCCC1(C)C'

# %%
m = Chem.MolFromSmiles(smilesCode)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-5c0d17d04a82> in <module>()
# ----> 1 m = Chem.MolFromSmiles(smilesCode)
#
# TypeError: No registered converter was able to produce a C++ rvalue of type class std::basic_string<wchar_t,struct std::char_traits<wchar_t>,class std::allocator<wchar_t> > from this Python object of type numpy.ndarray

# %%
mol = MolFromSmiles(smilesCode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e607fe46ffc5> in <module>()
# ----> 1 mol = MolFromSmiles(smilesCode)
#
# NameError: name 'MolFromSmiles' is not defined

# %%
import sys
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
from concurrent import futures

# %%
import progressbar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-aa73c21ff055> in <module>()
# ----> 1 import progressbar
#
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\progressbar\__init__.py in <module>()
#      56     pass
#      57
# ---> 58 from progressbar.compat import *
#      59 from progressbar.widgets import *
#      60
#
# ImportError: No module named compat

# %%
max_workers=4

# %%
def generateconformations(m, n):
    m = Chem.AddHs(m)
    ids=AllChem.EmbedMultipleConfs(m, numConfs=n, params=AllChem.ETKDG())
    return m, list(ids)

# %%
smi_input_file, sdf_output_file = sys.argv[1:3]

# %%
n = int(sys.argv[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-040406575523> in <module>()
# ----> 1 n = int(sys.argv[3])
#
# IndexError: list index out of range

# %%
rdkit.Chem.AddHs(smilesCode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6f6a7598f131> in <module>()
# ----> 1 rdkit.Chem.AddHs(smilesCode)
#
# NameError: name 'rdkit' is not defined

# %%
Chem.AddHs(smilesCode)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-33-d74f79eebf5a> in <module>()
# ----> 1 Chem.AddHs(smilesCode)
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdmolops.AddHs(numpy.ndarray)
# did not match C++ signature:
#     AddHs(class RDKit::ROMol mol, bool explicitOnly=False, bool addCoords=False, class boost::python::api::object onlyOnAtoms=None)
