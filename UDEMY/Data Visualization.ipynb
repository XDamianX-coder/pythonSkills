# %% [markdown]
# Installing seaborn

# %% [markdown]
# # Histograms

# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(250)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3., 12., 14., 28., 46., 60., 37., 33., 13.,  4.]),
#  array([-2.80192421, -2.27743536, -1.75294651, -1.22845765, -0.7039688 ,
#         -0.17947995,  0.3450089 ,  0.86949776,  1.39398661,  1.91847546,
#          2.44296432]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(160)

# %%
plt.hist(dataset2)
# Out:
# (array([ 4.,  6., 17., 18., 37., 33., 16., 21.,  4.,  4.]),
#  array([-2.18844612, -1.73918155, -1.28991697, -0.8406524 , -0.39138782,
#          0.05787675,  0.50714132,  0.9564059 ,  1.40567047,  1.85493505,
#          2.30419962]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset2,color='red')
# Out:
# (array([ 4.,  6., 17., 18., 37., 33., 16., 21.,  4.,  4.]),
#  array([-2.18844612, -1.73918155, -1.28991697, -0.8406524 , -0.39138782,
#          0.05787675,  0.50714132,  0.9564059 ,  1.40567047,  1.85493505,
#          2.30419962]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='green',alpha=0.7)
# Out:
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\matplotlib\axes\_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# (array([0.02287942, 0.09151767, 0.10677062, 0.21354124, 0.35081775,
#         0.45758837, 0.2821795 , 0.2516736 , 0.09914415, 0.03050589]),
#  array([-2.80192421, -2.27743536, -1.75294651, -1.22845765, -0.7039688 ,
#         -0.17947995,  0.3450089 ,  0.86949776,  1.39398661,  1.91847546,
#          2.44296432]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1,normed=True,color='green',alpha=0.5,bins=15)
plt.hist(dataset2,normed=True,alpha=0.5,bins=15)
# Out:
# (array([0.04173487, 0.08346975, 0.08346975, 0.31301155, 0.14607206,
#         0.27127668, 0.58428822, 0.43821617, 0.43821617, 0.2295418 ,
#         0.33387898, 0.20867437, 0.06260231, 0.06260231, 0.04173487]),
#  array([-2.18844612, -1.88893641, -1.58942669, -1.28991697, -0.99040726,
#         -0.69089754, -0.39138782, -0.09187811,  0.20763161,  0.50714132,
#          0.80665104,  1.10616076,  1.40567047,  1.70518019,  2.00468991,
#          2.30419962]),
#  <a list of 15 Patch objects>)

# %%
data1 = randn(1250)
data2=randn(1250)

# %%
sns.jointplot(data1,data2)

# %%
sns.jointplot(data1,data2,kind='hex')

# %% [markdown]
# # Kernel Density Estimate Plots

# %% [markdown]
# wszystko zaimportwoać

# %%
dataset = randn(125)

# %%
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)
plt.ylim(0,0.2)
# Out:
# (0, 0.2)

# %%
plt.hist(dataset,alpha=0.3)
sns.rugplot(dataset)

# %%
sns.rugplot(dataset)
x_min = dataset.min() -2
x_max = dataset.max() +2

x_axis = np.linspace(x_min,x_max,100)
bandwidth = ( (4*dataset.std()**5/(3*len(dataset))))**0.2

kernel_list =[]
for data_point in dataset:
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    kernel = kernel /kernel.max()
    kernel = kernel *0.4
    plt.plot(x_axis,kernel,color='yellow',alpha=0.5)
plt.ylim(0,1)
# Out:
# (0, 1)

# %%
sns.rugplot(dataset)
x_min = dataset.min() -2
x_max = dataset.max() +2

x_axis = np.linspace(x_min,x_max,100)
bandwidth = ( (4*dataset.std()**5/(3*len(dataset))))**0.2

kernel_list =[]
for data_point in dataset:
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    kernel = kernel /kernel.max()
    kernel = kernel *0.4
    plt.plot(x_axis,kernel,color='yellow',alpha=0.5)
plt.ylim(0,0.3)
# Out:
# (0, 0.3)

# %%
sum_of_kde = np.sum(kernel_list,axis=0)
fig = plt.plot(x_axis,sum_of_kde,color='green')

sns.rugplot(dataset)
plt.yticks([])
plt.suptitle("Sum of the basis functions")
# Out:
# Text(0.5,0.98,'Sum of the basis functions')

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset,color='black')
for bw in np.arange(0.5,2,0.25):
    sns.kdeplot(dataset,bw=bw,lw=1.8,label=bw)

# %% [markdown]
# url to check

# %%
kernel_options = ['biw','cos','epa','gau','triw']

for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern)

# %%
kernel_options = ['biw','cos','epa','gau','triw']

for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True)

# %%
sns.kdeplot(dataset,vertical=True)

# %% [markdown]
# url check

# %%
sns.kdeplot(dataset,cumulative = True)

# %%
mean = [0,0]
cov = [[1,0],[0,10]]
dataset3 = np.random.multivariate_normal(mean,cov,10000)
dframe = pd.DataFrame(dataset3,columns=['X','Y'])

sns.kdeplot(dframe)
# Out:
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\seaborn\distributions.py:679: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
sns.kdeplot(dframe.X,dframe.Y)

# %%
sns.kdeplot(dframe.X,dframe.Y,shade=True)

# %%
sns.kdeplot(dframe,bw=0.5)

# %%
sns.kdeplot(dframe,bw='silverman')

# %%
sns.jointplot('X','Y',dframe,kind='kde')

# %% [markdown]
# Ćwiczenia

# %%
dataset = randn(1250)

# %%
sns.rugplot(dataset)
plt.ylim(0,0.25)
# Out:
# (0, 0.25)

# %%
sns.rugplot(dataset)
plt.ylim(0,0.15)
# Out:
# (0, 0.15)

# %%
sns.rugplot(dataset)
plt.ylim(0,0.015)
# Out:
# (0, 0.015)

# %%
sns.rugplot(dataset)
plt.ylim(0,0.00015)
# Out:
# (0, 0.00015)

# %% [markdown]
# określa zakres

# %%
plt.hist(dataset,alpha=0.1)
sns.rugplot(dataset)

# %% [markdown]
# tworzy 'pudełka' co 0.1 itd.

# %%
sns.rugplot(dataset)
x_min = dataset.min() -0.001
x_max = dataset.max() +0.001
x_axis = np.linspace(x_min,x_max,10)
bandwidth = ((4*dataset.std()**5/(3*len(dataset))))**0.2
kernel_list = []
for data_point in dataset:
    kernel = stats.norm(data_point,bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    kernel = kernel / kernel.max()
    kernel = kernel *0.4
    plt.plot(x_axis,kernel,color='gray',alpha=0.1)
plt.ylim(0,0.5)
# Out:
# (0, 0.5)

# %% [markdown]
# ok, jasne

# %%
sum_of_kde = np.sum(kernel_list,axis=0)
fig = plt.plot(x_axis,sum_of_kde,color='blue')

sns.rugplot(dataset)
plt.yticks([])
plt.suptitle("Sum up")
# Out:
# Text(0.5,0.98,'Sum up')

# %%
sns.kdeplot(dataset)

# %%
sns.rugplot(dataset,color='grey')
for bw in np.arange(0.2,2,0.2):
    sns.kdeplot(dataset,bw=bw,lw=1.2,label=bw)

# %%
sns.rugplot(dataset,color='grey')
for bw in np.arange(0.1,3,0.1):
    sns.kdeplot(dataset,bw=bw,lw=1.0,label=bw)

# %%
sns.rugplot(dataset,color='grey')
for bw in np.arange(0.0,10,1):
    sns.kdeplot(dataset,bw=bw,lw=0.5,label=bw)

# %%
sns.rugplot(dataset,color='grey')
for bw in np.arange(0.0,10,1):
    sns.kdeplot(dataset,bw=bw,lw=5,label=bw)

# %%
kernel_options = ['biw','cos','epa','gau','triw']

for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern)

# %% [markdown]
# róne rodzaje 'kerneli'

# %%
kernel_options = ['biw','cos','epa','gau','triw']

for kern in kernel_options:
    sns.kdeplot(dataset,kernel=kern,label=kern,shade=True)

# %%
sns.kdeplot(dataset,vertical=True)

# %%
sns.kdeplot(dataset,cumulative = True)

# %%
mean = [1,2]
cov = [[12,50],[50,100]]
dataset = np.random.multivariate_normal(mean,cov,100000)
dframe = pd.DataFrame(dataset,columns=['X','Y'])

sns.kdeplot(dframe)
# Out:
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sns.kdeplot(dframe.X,dframe.Y)

# %%
sns.jointplot('X','Y',dframe,kind='kde')

# %% [markdown]
# # Combining Plot Styles

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
dataset = randn(1000)

# %%
sns.distplot(dataset,bins=20)

# %%
sns.distplot(dataset,bins=25,rug=True)

# %%
sns.distplot(dataset,bins=25,rug=True,hist=False)

# %%
sns.distplot(dataset,bins=25,
            kde_kws={'color':'red','label':'KDE PLOT'},
            hist_kws={'color':'grey','label':'HIST'})

# %%
from pandas import Series

ser = Series(dataset,name='My_data')
ser
# Out:
# 0     -0.843815
# 1      0.767502
# 2      1.686761
# 3      1.891591
# 4      0.932271
# 5      1.784410
# 6      0.787659
# 7      1.226295
# 8      0.066294
# 9      1.561237
# 10     0.092176
# 11    -2.169358
# 12     0.393308
# 13     0.850976
# 14    -1.434721
# 15    -0.237163
# 16     0.377644
# 17    -0.678765
# 18     0.824218
# 19    -2.042367
# 20    -1.100390
# 21    -1.148905
# 22    -1.078267
# 23     0.704128
# 24    -0.073203
# 25     0.511699
# 26     1.569009
# 27     1.881303
# 28     0.082080
# 29     1.173603
#          ...
# 970    0.348298
# 971    0.777701
# 972   -0.597926
# 973    0.797472
# 974    0.142466
# 975   -0.437654
# 976   -0.873876
# 977   -0.036490
# 978    0.409101
# 979    0.321977
# 980    1.562566
# 981    0.179886
# 982    0.420553
# 983    0.341659
# 984   -0.458156
# 985   -1.622862
# 986   -0.972714
# 987    0.661977
# 988   -0.931874
# 989    0.579859
# 990    0.028994
# 991   -0.379332
# 992   -1.230800
# 993   -2.332570
# ...

# %%
sns.distplot(ser,bins=250)

# %% [markdown]
# # Box and Violin Plots

# %% [markdown]
# import funkcji

# %%
data3 = randn(1000)

# %%
data4 = randn(1000)

# %%
sns.boxplot(data3,data4)

# %%
sns.boxplot([data3,data4],whis=np.inf)

# %%
data5 = randn(150)
data6 = randn(150)

# %%
sns.boxplot(data5,data6)

# %%
sns.boxplot([data5,data6],whis=np.inf)

# %%
data5 = randn(100)
data6 = randn(100)

# %%
sns.boxplot(data5,data6)

# %%
sns.boxplot([data5,data6],whis=np.inf)

# %%
sns.boxplot(data5,vert=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7599e0e864d9> in <module>()
# ----> 1 sns.boxplot(data5,vert=False)
#
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\seaborn\categorical.pyc in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2235     kwargs.update(dict(whis=whis, notch=notch))
#    2236
# -> 2237     plotter.plot(ax, kwargs)
#    2238     return ax
#    2239
#
# C:\Users\DamianAleksanderMiko\Anaconda3\envs\testenv\lib\site-packages\seaborn\categorical.pyc in plot(self, ax, boxplot_kws)
#     547     def plot(self, ax, boxplot_kws):
#     548         """Make the plot."""
# --> 549         self.draw_boxplot(ax, boxplot_kws)
#     550         self.annotate_axes(ax)
#     551         if self.orient == "h":
#
# ...

# %%
sns.boxplot(data5,orient = "v")

# %% [markdown]
# https://stackoverflow.com/questions/39937140/seaborn-boxplot-typeerror-unsupported-operand-types-for-str-and-int

# %%
data = stats.norm(0,10).rvs(100)
data9 = np.concatenate([stats.gamma(10).rvs(50)-1,
                       -1*stats.gamma(10).rvs(50)])
sns.boxplot([data,data9],whis=np.inf)

# %%
data = stats.norm(0,10).rvs(100)
data9 = np.concatenate([stats.gamma(10).rvs(50)-1,
                       -1*stats.gamma(10).rvs(50)])
sns.boxplot([data,data9])

# %%
data = stats.norm(0,10).rvs(100)
data9 = np.concatenate([stats.gamma(10).rvs(50)-1,
                       -1*stats.gamma(10).rvs(50)])
sns.boxplot([data,data9],whis=np.inf,orient='v')

# %%
data = stats.norm(0,10).rvs(100)
data9 = np.concatenate([stats.gamma(10).rvs(50)-1,
                       -1*stats.gamma(10).rvs(50)])
sns.boxplot([data,data9],whis=np.inf)

# %% [markdown]
# ???? inaczej niż na filmie, gdzie są rozdzielnie narysowane

# %%
sns.violinplot([data,data9])

# %%
sns.violinplot([data])
sns.violinplot([data9])

# %%
sns.violinplot(data9,bw=0.2)

# %%
sns.violinplot(data9,bw=0.02)

# %%
sns.violinplot(data,inner='stick')

# %% [markdown]
# # Regression Plots

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
tips1 = sns.load_dataset('tips')

# %%
tips1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill','tip',tips1)

# %%
sns.lmplot('total_bill','tip',tips1,
          scatter_kws={'marker':'O','color':'green'},
          line_kws={'linewidth':1,'color':'red'})

# %%
sns.lmplot('total_bill','tip',tips1,order=4,
          scatter_kws={'marker':'O','color':'green'},
          line_kws={'linewidth':1,'color':'red'})

# %%
sns.lmplot('total_bill','tip',tips1,fit_reg=False)

# %%
tips1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips1['tip_pect']=100*(tips1['tip']/tips1['total_bill'])

# %%
tips1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot('size','tip_pect',tips1)

# %% [markdown]
# url znaleźć Jitter wikipedia

# %%
sns.lmplot('size','tip_pect',tips1,x_jitter=.1)

# %%
sns.lmplot('size','tip_pect',tips1,x_jitter=.2)

# %%
sns.lmplot('size','tip_pect',tips1,x_estimator=np.mean)

# %%
sns.lmplot('total_bill','tip_pect',tips1,hue='sex',markers=['x','o'])

# %%
sns.lmplot('total_bill','tip_pect',tips1,hue='day')

# %% [markdown]
# local regression wikipedai

# %%
sns.lmplot('total_bill','tip_pect',tips1,lowess=True,line_kws={'color':'grey'})

# %%
sns.regplot('total_bill','tip_pect',tips1)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)
sns.regplot('total_bill','tip_pect',tips1,ax=axis1)
sns.violinplot(tips1['tip_pect'],tips1['size'],color='green',ax=axis2)

# %%
fig, (axis1,axis2) = plt.subplots(1,2,sharey=True)
sns.regplot('total_bill','tip_pect',tips1,ax=axis1)
sns.violinplot(tips1['size'],tips1['tip_pect'],color='green',ax=axis2)

# %% [markdown]
# invert according to tutorial

# %% [markdown]
# # Heatmaps and Clustered Matrices

# %% [markdown]
# import as normal

# %%
flight_dframe = sns.load_dataset('flights')

# %%
flight_dframe.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flight_dframe
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
flight_dframe = flight_dframe.pivot('month','year','passengers')

# %%
flight_dframe
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(flight_dframe)

# %%
sns.heatmap(flight_dframe,annot=True,fmt='d')

# %%
sns.heatmap(flight_dframe,center=flight_dframe.loc['January',1955])

# %%
f,(axis1,axis2) = plt.subplots(2,1)

yearly_flights = flight_dframe.sum()
years = pd.Series(yearly_flights.index.values)
years = pd.DataFrame(years)
flights = pd.Series(yearly_flights.values)
flights = pd.DataFrame(flights)
year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns = ['Year','Flights']

sns.barplot('Year',y='Flights',data=year_dframe,ax=axis1)
sns.heatmap(flight_dframe,cmap='Reds',ax=axis2,cbar_kws={'orientation':'horizontal'})

# %% [markdown]
# I have not add s in plt.subplot...

# %%
# heatmap() can be used on an axes for a subplot to create more informative figures
f, (axis1,axis2) = plt.subplots(2,1)

yearly_flights = flight_dframe.sum()

# Since yearly_flights is a weird format, we'll have to grab the values we want with a Series, then put them in a dframe

years = pd.Series(yearly_flights.index.values)
years = pd.DataFrame(years)

flights = pd.Series(yearly_flights.values) 
flights = pd.DataFrame(flights)

# Make the dframe and name columns
year_dframe = pd.concat((years,flights),axis=1)
year_dframe.columns = ['Year','Flights']



# Create the bar plot on top
sns.barplot('Year',y='Flights',data=year_dframe, ax = axis1)

# Create the heatmap on bottom
sns.heatmap(flight_dframe,cmap='Blues',ax=axis2,cbar_kws={"orientation": "horizontal"})

# %%
sns.clustermap(flight_dframe)

# %%
sns.clustermap(flight_dframe,col_cluster=False)

# %%
sns.clustermap(flight_dframe,standard_scale=1)

# %%
sns.clustermap(flight_dframe,standard_scale=0)

# %%
sns.clustermap(flight_dframe,z_score=1)
